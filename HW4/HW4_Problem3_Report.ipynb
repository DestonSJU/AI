# %% [markdown]
# <a href="https://colab.research.google.com/github/DestonSJU/AI/blob/main/HW4/HW4_Problem3_Report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Deston Willis
#
# Articial Intelligence
#
# 2/27/24
#
# HW4 Q3:Report on how changing α and β affects the path of a maze given by the A* algorithm

# %% [markdown]
# In order to implent the modified algorithm I first created two variables called alpha and beta to represent α and β respectfully. I would then change these values for whatever α and β I wanted to use.

# %%
#### Values for α and β
     alpha = 1
     beta = 1

# %% [markdown]
# Then I added these variables to the equation that calculates f(n) by multplying g(n) by alpha and h(n) by beta.

# %%
### Update the evaluation function for the cell n: f(n) = g(n) + h(n)
    self.cells[new_pos[0]][new_pos[1]].f = alpha * new_g + beta * self.cells[new_pos[0]][new_pos[1]].h
    self.cells[new_pos[0]][new_pos[1]].parent = current_cell

# %% [markdown]
# Question 1:
#
# ![Screenshot (194).png](data:image/png;base64,...)

# %% [markdown]
# After looking at different values for α and β, I found that as α becomes increasingly larger than β, the algorithm puts more weight on direct cost and looks more and more like Dijkstra's algorithm. I found that as β becomes increasingly larger than α, the algorithm puts more weight on the heuristic and looks more and more like Greedy Best-First Search.

# %% [markdown]
# Question 2: I ran the algorithm with α = 1 each time and β equal to 0.5, 2, 4, 6, and 8 to see how changing β would influence the path given.

# %% [markdown]
# β = 0.5
#
# ![Screenshot (200).png](data:image/png;base64,...)
#
# This path looks the same as the path generated when α and β both equal 1. While the heuristic is weighted less than with unweighted A*, since increasing the heuristic will lead the path to go towards the wall, the path doesn't change since in the path never goes towards the wall and goes around it in the unweighted A* algorithm

# %% [markdown]
# β = 2
#
# ![Screenshot (196).png](data:image/png;base64,...)
#
# This path is similar to the unweighted A* algorithm, but does go slightly to the right before going down and around the wall. This is because the heuristic will guide the path towards the wall but isn't weighted high enough to affect the ath that much.

# %% [markdown]
# β = 4
#
# ![Screenshot (197).png](data:image/png;base64,...)
#
# This path goes towards the right wall more than the β = 2 path does before evntually going around the wall to the goal. Since the heuristic is weighted more than the previous path, it will influence f(n) more and push the path towards the wall more since that is where the Greedy Best-First path goes.

# %% [markdown]
# β = 6
#
# ![Screenshot (198).png](data:image/png;base64,...)
#
# Similiar and more than the β = 4 path, this path goes towards the right wall before evntually going around the wall to the goal. Since the heuristic is weighted more than the previous path, it will influence f(n) more and push the path towards the wall more and make the path look more like the Greedy Best-First path, where the heurstic is the only thing that is considered. I am also noticing that based on the numbers I am using, the initial increases to β had more of an impact on the path than the later ones.

# %% [markdown]
# β = 8
#
# ![Screenshot (199).png](data:image/png;base64,...)
#
# This path is the exact same as the path when Similiar and more than the β = 6. This supports the idea that the beginning increases to the weigth of h(n) have more of an impact than the later ones. While the weight of the heurstic went up from the last path, it doesn't change because the difference in weight of the heuristic wasn't enough to affect the path.

# %% [markdown]
# Overall, with this specific maze lowering β doesn't change the path because the heurstic guides the path towards the wall and the unweighted path doesn't go towards the wall and immediately goes around it. On the other hand, if β goes up then the path will be guided more and more towards the wall before having to go back around it to the goal. The initial increases affect the path more, while the more β is increased, the less additional effect it provides.
